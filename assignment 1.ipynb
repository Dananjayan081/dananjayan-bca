# %%
from bs4 import BeautifulSoup

# %%
import pandas as py

# %%
import numpy as np

# %%
import requests

# %%
url="https://www.flipkart.com/search?q=sony+cameras&sid=jek%2Cp31%2Ctrv&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_11_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_11_na_na_na&as-pos=1&as-type=RECENT&suggestionId=sony+cameras%7CDSLR+%26+Mirrorless&requestId=c71da817-e768-4888-b874-44eed627aca6&as-searchtext=sony%20camera"

# %%
permission=requests.get(url)

# %%
permission
# Out:
# <Response [200]>

# %%
cov_Text=BeautifulSoup(permission.text)

# %%
cov_Text
# Out:
# <!DOCTYPE html>
# ...

# %%
camera=cov_Text.select("._4rR01T")

# %%
camera
# Out:
# [<div class="_4rR01T">SONY ZV-E10L Mirrorless Camera Body with 1650 mm Power Zoom Lens Vlog Camera</div>,
#  <div class="_4rR01T">SONY ZV-E10 Mirrorless Camera Body Only Vlog Camera</div>,
#  <div class="_4rR01T">SONY Alpha ILCE-6600M APS-C Mirrorless Camera with 18-135 mm Zoom Lens Featuring Eye AF and 4K movie r...</div>,
#  <div class="_4rR01T">SONY Alpha ILCE-6400M APS-C Mirrorless Camera with 18-135 mm Zoom Lens Featuring Eye AF and 4K movie r...</div>,
#  <div class="_4rR01T">SONY ZV-E10L Vlogger Kit Mirrorless Camera Body with 16-50mm Lens,Bluetooth&amp;Lavalier Mic,Shooting Grip...</div>,
#  <div class="_4rR01T">SONY Alpha ILCE-7SM3 Full Frame Mirrorless Camera Body Featuring Eye AF and 4K movie recording</div>,
#  <div class="_4rR01T">SONY Alpha ILCE-7C Full Frame Mirrorless Camera Body Featuring Eye AF and 4K movie recording</div>,
#  <div class="_4rR01T">SONY Alpha ILCE-6600 APS-C Mirrorless Camera Body Only Featuring Eye AF and 4K movie recording</div>,
# ...

# %%
warranty=cov_Text.select(".rgWa7D:nth-child(6)")

# %%
warranty
# Out:
# [<li class="rgWa7D">2 Year Warranty</li>,
#  <li class="rgWa7D">2 Year Warranty</li>,
#  <li class="rgWa7D">2 Year Warranty</li>,
#  <li class="rgWa7D">2 Year Warranty</li>,
#  <li class="rgWa7D">2 Years Warranty</li>,
#  <li class="rgWa7D">2 Year Warranty</li>,
#  <li class="rgWa7D">2 Year Warranty</li>,
#  <li class="rgWa7D">2 Year Warranty</li>,
#  <li class="rgWa7D">2 Year Warranty</li>,
#  <li class="rgWa7D">2 Years Warranty</li>,
#  <li class="rgWa7D">2 Years Warranty</li>,
#  <li class="rgWa7D">2 Year Warranty</li>,
#  <li class="rgWa7D">2 Years Warranty</li>]

# %%
tab=py.DataFrame({'camera':camera,'warranty':warranty})
tab
# Out:
#                                                camera            warranty
# 0   [SONY ZV-E10L Mirrorless Camera Body with 1650...   [2 Year Warranty]
# 1   [SONY ZV-E10 Mirrorless Camera Body Only Vlog ...   [2 Year Warranty]
# 2   [SONY Alpha ILCE-6600M APS-C Mirrorless Camera...   [2 Year Warranty]
# 3   [SONY Alpha ILCE-6400M APS-C Mirrorless Camera...   [2 Year Warranty]
# 4   [SONY ZV-E10L Vlogger Kit Mirrorless Camera Bo...  [2 Years Warranty]
# 5   [SONY Alpha ILCE-7SM3 Full Frame Mirrorless Ca...   [2 Year Warranty]
# 6   [SONY Alpha ILCE-7C Full Frame Mirrorless Came...   [2 Year Warranty]
# 7   [SONY Alpha ILCE-6600 APS-C Mirrorless Camera ...   [2 Year Warranty]
# 8   [SONY Alpha ILCE-7CL Full Frame Mirrorless Cam...   [2 Year Warranty]
# 9   [SONY Alpha ILCE-7M4K Full Frame Mirrorless Ca...  [2 Years Warranty]
# 10  [SONY Alpha ILCE-7RM3A Full Frame Mirrorless C...  [2 Years Warranty]
# 11  [SONY Alpha ILCE-7C Full Frame Mirrorless Came...   [2 Year Warranty]
# ...

# %%
tab.to_csv("C:/assignment 1/assignment.csv")

# %%
df=py.read_csv("C:/assignment 1/assignment.csv")
df
# Out:
#     Unnamed: 0                                             camera
# 0            0  <div class="_4rR01T">SONY ZV-E10L Mirrorless C...  \
# 1            1  <div class="_4rR01T">SONY ZV-E10 Mirrorless Ca...
# 2            2  <div class="_4rR01T">SONY Alpha ILCE-6600M APS...
# 3            3  <div class="_4rR01T">SONY Alpha ILCE-6400M APS...
# 4            4  <div class="_4rR01T">SONY ZV-E10L Vlogger Kit ...
# 5            5  <div class="_4rR01T">SONY Alpha ILCE-7SM3 Full...
# 6            6  <div class="_4rR01T">SONY Alpha ILCE-7C Full F...
# 7            7  <div class="_4rR01T">SONY Alpha ILCE-6600 APS-...
# 8            8  <div class="_4rR01T">SONY Alpha ILCE-7CL Full ...
# 9            9  <div class="_4rR01T">SONY Alpha ILCE-7M4K Full...
# 10          10  <div class="_4rR01T">SONY Alpha ILCE-7RM3A Ful...
# 11          11  <div class="_4rR01T">SONY Alpha ILCE-7C Full F...
# 12          12  <div class="_4rR01T">SONY Alpha ILCE-7RM4 Full...
#
# ...
